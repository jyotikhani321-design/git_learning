# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotikhani321-design/git_learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number =10
if (number%2==0):
  print("even")
else:
  print("odd")
# Out:
# even

# %%
import pandas as pd
df=pd.read_excel("data.xlsx")
print("Original columns:", df.columns)
df.columns = df.columns.str.strip()
print("Stripped columns:", df.columns)
print(df.describe())
# Out:
# Original columns: Index(['month ', 'sales'], dtype='object')
# Stripped columns: Index(['month', 'sales'], dtype='object')
#        month sales
# count      0     0
# unique     0     0
# top      NaN   NaN
# freq     NaN   NaN

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import matplotlib.pyplot as plt
plt.plot(df['month'], df['sales'], marker='o', color='red')
plt.title('Monthly Sales Trend')
plt.show()
